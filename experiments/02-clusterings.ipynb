# %%
import numpy as np
import torch
import faiss

from misc import load_embeddings
from misc import ALL_N_CLUSTERS, ALL_ASSIGNMENTS_PATHS

# %%
embs = load_embeddings()
X = torch.from_numpy(embs).float()

# %%
def _to_faiss_array(tensor: torch.Tensor) -> np.ndarray:
    array = np.asarray(tensor.cpu())
    array = array.astype('float32')
    array = np.ascontiguousarray(array)
    faiss.normalize_L2(array)
    return array

def fit_spherical_kmeans(
        context: torch.Tensor,
        n_clusters: int=1024,
):
    X = _to_faiss_array(context)
    km = faiss.Kmeans(d=X.shape[1], k=n_clusters, spherical=True, gpu=False, verbose=True)
    km.train(X)
    return km.centroids

# %%
for n_clusters, assignments_path in zip(ALL_N_CLUSTERS, ALL_ASSIGNMENTS_PATHS):
    print(f"Fitting spherical k-means with {n_clusters} clusters...")
    cluster_centers = fit_spherical_kmeans(
        X,
        n_clusters=n_clusters,
    )
    assignments = faiss.knn(
        _to_faiss_array(X),
        cluster_centers,
        k=1,
    )[1].squeeze()
    np.save(assignments_path, assignments)
print("Done.")
# Out:
# Fitting spherical k-means with 1 clusters...
# Sampling a subset of 256 / 98348 for training
# Clustering 256 points in 1536D to 1 clusters, redo 1 times, 25 iterations
#   Preprocessing in 0.04 s
#   Iteration 24 (0.01 s, search 0.01 s): objective=79.5851 imbalance=1.000 nsplit=0
# Fitting spherical k-means with 2 clusters...
# Sampling a subset of 512 / 98348 for training
# Clustering 512 points in 1536D to 2 clusters, redo 1 times, 25 iterations
#   Preprocessing in 0.04 s
#   Iteration 24 (0.01 s, search 0.01 s): objective=172.977 imbalance=1.132 nsplit=0
# Fitting spherical k-means with 4 clusters...
# Sampling a subset of 1024 / 98348 for training
# Clustering 1024 points in 1536D to 4 clusters, redo 1 times, 25 iterations
#   Preprocessing in 0.04 s
#   Iteration 24 (0.02 s, search 0.02 s): objective=374.798 imbalance=1.025 nsplit=0
# Fitting spherical k-means with 8 clusters...
# Sampling a subset of 2048 / 98348 for training
# Clustering 2048 points in 1536D to 8 clusters, redo 1 times, 25 iterations
#   Preprocessing in 0.04 s
#   Iteration 24 (0.05 s, search 0.04 s): objective=799.161 imbalance=1.082 nsplit=0
# Fitting spherical k-means with 16 clusters...
# Sampling a subset of 4096 / 98348 for training
# Clustering 4096 points in 1536D to 16 clusters, redo 1 times, 25 iterations
#   Preprocessing in 0.04 s
#   Iteration 24 (0.13 s, search 0.11 s): objective=1722.07 imbalance=1.082 nsplit=0
# Fitting spherical k-means with 32 clusters...
# Sampling a subset of 8192 / 98348 for training
# Clustering 8192 points in 1536D to 32 clusters, redo 1 times, 25 iterations
#   Preprocessing in 0.05 s
#   Iteration 24 (0.44 s, search 0.41 s): objective=3670.75 imbalance=1.247 nsplit=0
# Fitting spherical k-means with 64 clusters...
# Sampling a subset of 16384 / 98348 for training
# Clustering 16384 points in 1536D to 64 clusters, redo 1 times, 25 iterations
#   Preprocessing in 0.07 s
#   Iteration 24 (1.19 s, search 1.13 s): objective=7762.08 imbalance=1.129 nsplit=0
# Fitting spherical k-means with 128 clusters...
# Sampling a subset of 32768 / 98348 for training
# Clustering 32768 points in 1536D to 128 clusters, redo 1 times, 25 iterations
#   Preprocessing in 0.11 s
#   Iteration 24 (3.38 s, search 3.28 s): objective=16387.7 imbalance=1.168 nsplit=0
# Fitting spherical k-means with 256 clusters...
# Sampling a subset of 65536 / 98348 for training
# Clustering 65536 points in 1536D to 256 clusters, redo 1 times, 25 iterations
#   Preprocessing in 0.15 s
#   Iteration 24 (12.66 s, search 12.46 s): objective=34453.5 imbalance=1.135 nsplit=0
# Fitting spherical k-means with 512 clusters...
# Clustering 98348 points in 1536D to 512 clusters, redo 1 times, 25 iterations
#   Preprocessing in 0.04 s
#   Iteration 24 (36.19 s, search 35.90 s): objective=54148.4 imbalance=1.177 nsplit=0
# Fitting spherical k-means with 1024 clusters...
# Clustering 98348 points in 1536D to 1024 clusters, redo 1 times, 25 iterations
#   Preprocessing in 0.04 s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_6763/1574398219.py in ?()
#       1 for n_clusters, assignments_path in zip(ALL_N_CLUSTERS, ALL_ASSIGNMENTS_PATHS):
#       2     print(f"Fitting spherical k-means with {n_clusters} clusters...")
# ----> 3     cluster_centers = fit_spherical_kmeans(
#       4         X,
#       5         n_clusters=n_clusters,
#       6     )
#
# /tmp/ipykernel_6763/1645671717.py in ?(context, n_clusters)
#      10         n_clusters: int=1024,
#      11 ):
#      12     X = _to_faiss_array(context)
#      13     km = faiss.Kmeans(d=X.shape[1], k=n_clusters, spherical=True, gpu=False, verbose=True)
# ---> 14     km.train(X)
#      15     return km.centroids
#
# /usr/local/lib/python3.10/dist-packages/faiss/extra_wrappers.py in ?(self, x, weights, init_centroids)
#     557             if init_centroids is not None:
#     558                 nc, d2 = init_centroids.shape
#     559                 assert d2 == d
#     560                 faiss.copy_array_to_vector(init_centroids.ravel(), clus.centroids)
# --> 561             clus.train(x, self.index, weights)
#     562         else:
#     563             # not supported for progressive dim
#     564             assert weights is None
#
# /usr/local/lib/python3.10/dist-packages/faiss/class_wrappers.py in ?(self, x, index, weights)
#      91             weights = np.ascontiguousarray(weights, dtype='float32')
#      92             assert weights.shape == (n, )
#      93             self.train_c(n, swig_ptr(x), index, swig_ptr(weights))
#      94         else:
# ---> 95             self.train_c(n, swig_ptr(x), index)
#
# /usr/local/lib/python3.10/dist-packages/faiss/swigfaiss.py in ?(self, n, x, index, x_weights)
#    2914         :param index:      index used for assignment
#    2915         :type x_weights: float, optional
#    2916         :param x_weights:  weight associated to each vector: NULL or size n
#    2917         """
# -> 2918         return _swigfaiss.Clustering_train(self, n, x, index, x_weights)
#
# KeyboardInterrupt:
